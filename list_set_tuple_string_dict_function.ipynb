# %%
# python
# JavaScript
# Node.js
# SQL
# mongoDB
# RESTful API
# Docker
# NoSQL

# %%
'collection  (itrable elements)'
# list
# tuple
# set
# dict
# array
# namedtuple
# frozenset
# oederdict
# defaultdict

# %%
# list -( Ordered, Indexed, mutable, allow duplicates, Hetrogenous )
# [] or list()
list1 =[]
list2 = list()
print(type(list1))
print(type(list2))
# Out:
# <class 'list'>
# <class 'list'>

# %%
# list methods
list3 = [1,2,3,4,5,2]

list3.copy()
# Out:
# [1, 2, 3, 4, 5, 2]

# %%
list3.count(2)      # count the no. of time element present in list.
# Out:
# 2

# %%
list3.extend([2,4,5])    # extend the list or add the element to the list.

# %%
list3
# Out:
# [1, 2, 3, 4, 5, 2, 2, 4, 5]

# %%
list3.index(5)    # give 1st index of search element.
# Out:
# 4

# %%
list3.insert(8,1)   # insert 1 element to list   list.insert(position,element)

# %%
list3
# Out:
# [1, 2, 3, 4, 5, 2, 2, 4, 1, 1, 5]

# %%
list3.clear()     # remove all element from the list.

# %%
list3
# Out:
# []

# %%
list3.append(3)      # add one element in the list at  the end.

# %%
list3
# Out:
# [3]

# %%
list3.extend([1,2,3])

# %%
list3
# Out:
# [3, 1, 2, 3]

# %%
list3.pop()     # remove or pop 1 element from last.
# Out:
# 3

# %%
list3
# Out:
# [3, 1, 2]

# %%
list3.reverse()       # reverse the list element of the list.

# %%
list3
# Out:
# [2, 1, 3]

# %%
list3.sort()      # sort the list assending ordered.

# %%
list3
# Out:
# [1, 2, 3]

# %%
list3.remove(2)        # remove any element from the list.

# %%
list3
# Out:
# [1, 3]

# %%
'# function  : A function is a block of code that runs only when you call it.
#        👉 It helps to reuse code and keep programs organized.  
# modularity
# reusability
# readability
# maintainability

'# types of functions'
# built in function
#  methods  : attached with any datatype.
# user define function
# lambda functions

def function_name():     # if fun(variable): we give parameter ;  fun(value): we give Argument.
    #function body
    #code
    print(value)

# %%
def open_file():
    print("file opened:")
def delet_file():
    print("file deleted:")
def save_file():
    print("file saved:")

# %%
open_file()
# Out:
# file opened:

# %%
save_file()
# Out:
# file saved:

# %%
def greatting(name):
    print(f" Hii {name} how are you!")

# %%
greatting("roshan")
# Out:
#  Hii roshan how are you!

# %%
import pandas as pd

# %%
pd.read_csv()      # press shift tab to see arguments and parameters.

# %%
'#  types of parameters'
# positional parameters
# keyword parameters
# position-only parameters(/)
# keyword-only parameters(*)
# default parameters
# variable-length positional parameters (*args)
# variable-length keywords parameters (**kwargs)
# Out:
# '#  types of parameters'

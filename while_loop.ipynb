# %%
# while condition:             (A while loop is used to repeat a block of code as long as a condition is True.)
#    statement

# %%
i = 1
while i<=5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
database_user_name = "roshan"
database_password = "rkm123"

attempt =0
Enter_user_name = input("Enter user name:")
Enter_password = input("Enter password:")

while database_user_name != Enter_user_name or database_password != Enter_password:
    Enter_user_name = input("Enter user name:")
    Enter_password = input("Enter password:")
    print("incorrect user_name and password:")
    attempt = attempt +1
    if attempt == 3:
        print("your all attempt is finish:")
        break
        
else:
    print("correct user_name and password:")
# Out:
# Enter user name: djwjd
# Enter password: dwidj
# Enter user name: kjsj
# Enter password: djkbwb
# incorrect user_name and password:
# Enter user name: dwhkb
# Enter password: dwjk
# incorrect user_name and password:
# Enter user name: dqjn
# Enter password: dwjkn
# incorrect user_name and password:
# your all attempt is finish:

# %%
while False:             #if we make True the infinite loop run and print Hello continuesly.
    print("Hello")
else:
    print("Bye")
# Out:
# Bye

# %%
'# Set '
# unordered
# unindexed
# mutable object
# do not allow duplicates element
# hetrogenious
# Out:
# '# Set '

# %%
set1 = {}
print(type(set1))
# Out:
# <class 'dict'>

# %%
set1 = {1}             # at least 1 element in it otherwise by default it creat dict.
print(type(set1))
# Out:
# <class 'set'>

# %%
set2 = set("roshanKKKKKK")
print(set2)
# Out:
# {'s', 'o', 'a', 'r', 'K', 'n', 'h'}

# %%
set3 = {11,"roshan",[1,2,3,4]}      # only take imutable object in set
print(set3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 set3 = {11,"roshan",[1,2,3,4]}
#       2 print(set3)
#
# TypeError: cannot use 'list' as a set element (unhashable type: 'list')

# %%
# set methods
set4 = {11,43,21}

# %%
set4.add(22)      # only take 1 agr and  add to set if it unique.
set4
# Out:
# {11, 21, 22, 43}

# %%
set4.clear()      # remove all element from set
set4
# Out:
# set()

# %%
seta = {11,21,22,43}
setb = {11,22}
print(seta.difference(setb))
seta
# Out:
# {43, 21}
# {11, 21, 22, 43}

# %%
seta = {11,21,22,43}
setb = {11,22}
print(seta.difference_update(setb))
seta
# Out:
# None
# {21, 43}

# %%
set4.discard(22)        # Unlike set.remove(), the discard() method does not raisean exception when an element is missing from the set.
